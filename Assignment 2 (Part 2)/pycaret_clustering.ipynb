# %% [markdown]
# # **Five Unsupervised Pycaret Workflow Steps**
# ## **1)Setup**
# ## **2)Create Model**
# ## **3)Assign Labels**
# ## **4)Analyze Model**
# ## **5)Save Model**

# %%
pip install pycaret

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as p
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Clustering**

# %% [markdown]
# ## **Setup**

# %%
df = p.read_csv('/content/drive/MyDrive/Data_Mining_CMPE_255/Clustering.csv')
from pycaret.clustering import *

# %%
cluster = ClusteringExperiment()
clustering = setup(df)
cluster.setup(df)
# Out:
# <style type="text/css">
# #T_d02fb_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d02fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d02fb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d02fb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d02fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d02fb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d02fb_row0_col1" class="data row0 col1" >6222</td>
#     </tr>
#     <tr>
#       <th id="T_d02fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d02fb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_d02fb_row1_col1" class="data row1 col1" >(4500, 7)</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## **Creating Model**

# %%
cluster_creator = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f7e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f7e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4f7e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4f7e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4f7e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4f7e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4f7e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f7e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f7e3_row0_col0" class="data row0 col0" >0.7174</td>
#       <td id="T_4f7e3_row0_col1" class="data row0 col1" >41498.6719</td>
# ...

# %% [markdown]
# ## **Assigning Labels**

# %%
labeling = assign_model(cluster_creator)
labeling
# Out:
#              A         B         C          D          E         F         G  \
# 0    -7.653842 -5.897334 -3.543707  -0.215847   5.401389 -5.630704 -1.745586
# 1    -6.086820 -3.324797 -2.720054  -1.615149   5.682705 -5.584185 -1.168945
# 2    -6.302665 -2.517686 -4.449976  -0.852940   6.193167 -5.710855  1.294016
# 3    -6.597867 -6.897920 -5.246505   0.275385  -1.657027 -5.436061  2.883139
# 4     6.991250  1.409749  3.699707 -10.892313  10.524631  8.250846 -4.775215
# ...        ...       ...       ...        ...        ...       ...       ...
# 4495 -6.703501 -3.776282 -1.974762  -1.237800   5.855438 -5.996473  0.272140
# 4496  8.912670  2.523429  3.674820  -9.598516   9.461580  5.920463 -6.665806
# 4497 -6.942439 -2.790206 -1.605197  -0.185214   4.624850 -6.281358  0.062402
# 4498  6.363550  2.387697  3.056783  -9.052670   8.204039  6.329845 -7.184947
# 4499  8.594052  1.677665  3.525195 -10.366898  10.042262  6.875916 -5.830440
#
#         Cluster
# 0     Cluster 3
# ...

# %% [markdown]
# ## **Analyze model**

# %%
plot_model(cluster_creator, plot = 'cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(cluster_creator, plot = 'elbow')

# %%
plot_model(cluster_creator, plot = 'silhouette')

# %% [markdown]
# ## **Saveing Model**

# %%
save_model(cluster_creator, 'cluster creator')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['A', 'B', 'C', 'D', 'E', 'F', 'G'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model', KMeans(n_clusters=4, random_state=6222))]),
#  'cluster creator.pkl')

# %%
load = load_model('cluster creator')
load
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['A', 'B', 'C', 'D', 'E', 'F', 'G'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('trained_model', KMeans(n_clusters=4, random_state=6222))])
